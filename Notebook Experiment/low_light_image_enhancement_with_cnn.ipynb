# %% [markdown]
# # Noisy and Low Light Image Enhancement with CNN

# %%
# try:
#     tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
#     print('Running on TPU ', tpu.master())
# except ValueError:
#     tpu = None

# if tpu:
#     tf.config.experimental_connect_to_cluster(tpu)
#     tf.tpu.experimental.initialize_tpu_system(tpu)
#     strategy = tf.distribute.experimental.TPUStrategy(tpu)
# else:
#     strategy = tf.distribute.get_strategy()

# print("REPLICAS: ", strategy.num_replicas_in_sync)

# %% [markdown]
# ## Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import os
import random
import cv2 as cv
import matplotlib.pyplot as plt
import matplotlib as mpl
import tensorflow as tf
from keras.preprocessing import image
from keras import backend as K
from keras.layers import add, Conv2D,MaxPooling2D,UpSampling2D,Input,BatchNormalization, RepeatVector, Reshape
from keras.layers import Dense, Dropout, Concatenate,Reshape, Conv2DTranspose,Conv2D, MaxPooling2D, LeakyReLU, UpSampling2D, Lambda
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator
from skimage.util import random_noise
from sklearn.preprocessing import MinMaxScaler
np.random.seed(1)
from skimage.exposure import adjust_gamma
import warnings
from tqdm import tqdm
warnings.simplefilter(action='ignore', category=FutureWarning)

mpl.rcParams['font.size'] = 10 # Set font size to 10
# mpl.rcParams['axes.edgecolor'] = 'white' # Set axis edge color to white
# mpl.rcParams['xtick.color'] = 'white' # Set x-axis tick color to white
# mpl.rcParams['ytick.color'] = 'white' # Set y-axis tick color to white

# %%
os.environ['KAGGLE_USERNAME'] = "XXXX"

# username from the json file

os.environ['KAGGLE_KEY'] = "XXXXXXXXXXXXXXXXXXX"

# key from the json file

# %%
# !kaggle datasets download -d duttadebadri/image-classification
# Out:
# Downloading image-classification.zip to /content
# 100% 2.34G/2.34G [00:25<00:00, 99.5MB/s]
# 100% 2.34G/2.34G [00:25<00:00, 99.8MB/s]

# %%
# !unzip -q "/content/image-classification.zip"

# %%
InputPath="/content/images/images/travel and  adventure/"

# %% [markdown]
# ### Let us define our function to add noise:

# %%
def noisy(image, gamma):
  image = random_noise(image, mode='gaussian', var = 0.001, clip=True)
  image = adjust_gamma(image, gamma=gamma, gain=1)
  return image

# %% [markdown]
# ## REAL IMAGE

# %%
img = cv.imread("/content/images/images/travel and  adventure/Places365_val_00005766.jpg")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
l = img.max()
plt.imshow(img/l)
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %% [markdown]
# ## IMAGE WITH NOISE(SALT AND PEPPER NOISE)

# %%
img = np.array(img/255.0, dtype = np.float32)
Noise = noisy(img, 5)
plt.imshow(Noise)
plt.axis('off')
Noise.max(), Noise.min()
# Out:
# (1.0, 0.0)

# %% [markdown]
# ### Model:

# %%
def create_model(shape=(400, 400, 3)):
  in_ = Input(shape)
  p_in_ = Conv2D(32,(3,3), activation='relu',padding='same',strides=1)(in_)

  model_1 = Conv2D(32,(3,3), activation='relu',padding='same',strides=1)(p_in_)
  model_1 = Conv2D(32,(3,3), activation='relu',padding='same',strides=1)(model_1)
  model_1 = Conv2D(32,(3,3), activation='relu',padding='same',strides=1)(model_1)
  model_2 = Conv2D(32,(1,1), activation='relu',padding='same',strides=1)(p_in_)
  model_add = add([model_1,model_2])
  model_3 = Conv2D(64,(3,3), activation='relu',padding='same',strides=1)(model_add)
  model_3 = Conv2D(32,(3,3), activation='relu',padding='same',strides=1)(model_3)
  model_3 = Conv2D(32,(3,3), activation='relu',padding='same',strides=1)(model_3)
  model_add_2 = add([model_add,model_3])

  model_1 = Conv2D(64,(3,3), activation='relu',padding='same',strides=1)(model_add_2)
  model_1 = Conv2D(64,(3,3), activation='relu',padding='same',strides=1)(model_1)
  model_1 = Conv2D(64,(3,3), activation='relu',padding='same',strides=1)(model_1)
  model_2 = Conv2D(64,(1,1), activation='relu',padding='same',strides=1)(model_add_2)
  model_add = add([model_1,model_2])
  model_3 = Conv2D(128,(3,3), activation='relu',padding='same',strides=1)(model_add)
  model_3 = Conv2D(64,(3,3), activation='relu',padding='same',strides=1)(model_3)
  model_3 = Conv2D(64,(3,3), activation='relu',padding='same',strides=1)(model_3)
  model_add_2 = add([model_add,model_3])

  model_1 = Conv2D(32,(3,3), activation='relu',padding='same',strides=1)(model_add_2)
  model_1 = Conv2D(32,(3,3), activation='relu',padding='same',strides=1)(model_1)
  model_1 = Conv2D(32,(3,3), activation='relu',padding='same',strides=1)(model_1)
  model_2 = Conv2D(32,(1,1), activation='relu',padding='same',strides=1)(model_add_2)
  model_add = add([model_1,model_2])
  model_3 = Conv2D(64,(3,3), activation='relu',padding='same',strides=1)(model_add)
  model_3 = Conv2D(32,(3,3), activation='relu',padding='same',strides=1)(model_3)
  model_3 = Conv2D(32,(3,3), activation='relu',padding='same',strides=1)(model_3)
  model_add_2 = add([model_add,model_3])
  out_ = Conv2D(3,(3,3), activation='relu',padding='same',strides=1)(model_add_2)
  Model_Enhancer = Model(inputs=in_, outputs=out_)
  return Model_Enhancer

# %%
def peak_signal_noise_ratio(y_true, y_pred):
    return tf.image.psnr(y_pred, y_true, max_val=1.0)

def ssim(y_true, y_pred):
    return tf.image.ssim( y_true, y_pred, max_val = 1.0)

def ms_ssim_l1(y_true, y_pred):
    max_picture_value = 1.0
    alpha = 0.5

    mae_loss = tf.reduce_mean(tf.abs((y_true) - (y_pred)))

    if mae_loss <= 0.05:
        msssim_loss = (1 - tf.image.ssim_multiscale(y_true, y_pred, max_picture_value))
    else:
        msssim_loss = (1 - tf.image.ssim(y_true, y_pred, max_picture_value))

    loss = (alpha * msssim_loss + (1-alpha) * mae_loss)

    return tf.reduce_mean(loss)



Model_Enhancer = create_model()

Model_Enhancer.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=0.0001),
                       loss= ms_ssim_l1, metrics=[peak_signal_noise_ratio, ssim])

Model_Enhancer.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 400, 400, 3  0           []
#                                 )]
#
#  conv2d_46 (Conv2D)             (None, 400, 400, 32  896         ['input_3[0][0]']
#                                 )
#
#  conv2d_47 (Conv2D)             (None, 400, 400, 32  9248        ['conv2d_46[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 400, 400, 32  9248        ['conv2d_47[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 400, 400, 32  9248        ['conv2d_48[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 400, 400, 32  1056        ['conv2d_46[0][0]']
#                                 )
#
#  add_12 (Add)                   (None, 400, 400, 32  0           ['conv2d_49[0][0]',
#                                 )                                 'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 400, 400, 64  18496       ['add_12[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 400, 400, 32  18464       ['conv2d_51[0][0]']
#                                 )
#
#  conv2d_53 (Conv2D)             (None, 400, 400, 32  9248        ['conv2d_52[0][0]']
#                                 )
#
#  add_13 (Add)                   (None, 400, 400, 32  0           ['add_12[0][0]',
#                                 )                                 'conv2d_53[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 400, 400, 64  18496       ['add_13[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 400, 400, 64  36928       ['conv2d_54[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 400, 400, 64  36928       ['conv2d_55[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 400, 400, 64  2112        ['add_13[0][0]']
#                                 )
#
#  add_14 (Add)                   (None, 400, 400, 64  0           ['conv2d_56[0][0]',
#                                 )                                 'conv2d_57[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 400, 400, 12  73856       ['add_14[0][0]']
#                                 8)
#
#  conv2d_59 (Conv2D)             (None, 400, 400, 64  73792       ['conv2d_58[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 400, 400, 64  36928       ['conv2d_59[0][0]']
#                                 )
#
#  add_15 (Add)                   (None, 400, 400, 64  0           ['add_14[0][0]',
#                                 )                                 'conv2d_60[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 400, 400, 32  18464       ['add_15[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 400, 400, 32  9248        ['conv2d_61[0][0]']
#                                 )
#
#  conv2d_63 (Conv2D)             (None, 400, 400, 32  9248        ['conv2d_62[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 400, 400, 32  2080        ['add_15[0][0]']
#                                 )
#
#  add_16 (Add)                   (None, 400, 400, 32  0           ['conv2d_63[0][0]',
#                                 )                                 'conv2d_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 400, 400, 64  18496       ['add_16[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 400, 400, 32  18464       ['conv2d_65[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 400, 400, 32  9248        ['conv2d_66[0][0]']
#                                 )
#
#  add_17 (Add)                   (None, 400, 400, 32  0           ['add_16[0][0]',
#                                 )                                 'conv2d_67[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 400, 400, 3)  867         ['add_17[0][0]']
#
# ==================================================================================================
# Total params: 441,059
# Trainable params: 441,059
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(Model_Enhancer,to_file='model_.png',show_shapes=True, show_layer_names=True)
from IPython.display import Image
Image(retina=True, filename='model_.png')

# %%
x, y = load_img(InputPath, train[:16])
x.shape, y.shape

# %%
Model_Enhancer.load_weights('/content/drive/MyDrive/Datasets/Images/Weights/')

# %% [markdown]
# ## Model finetuning on LOL dataset

# %%
import random
noise_dir = "/content/drive/MyDrive/Datasets/LowLight/our485/low/"
img_dir = "/content/drive/MyDrive/Datasets/LowLight/our485/high/"
img_list = os.listdir(img_dir)
img_list = np.array(img_list)
val = random.choices(img_list, k=50)
key = [x not in val for x in img_list]
train = img_list[key]
len(train), len(val)
# Out:
# (437, 50)

# %%
img = cv.imread(img_dir+train[78])
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img = cv.resize(img,(400, 600))
img.shape
# Out:
# (600, 400, 3)

# %%
# Dataloader

def load_img(img_dir, noise_dir, img_list):
    images=[]
    noisy_images = []
    for i, image_name in enumerate(img_list):
        try:
            img = cv.imread(img_dir+image_name)
            img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
            img = cv.resize(img,(400, 400))
            img = np.array(img/255.0, dtype = np.float32)
            img_transformed = cv.imread(noise_dir+image_name)
            img_transformed = cv.cvtColor(img, cv.COLOR_BGR2RGB)
            img_transformed = cv.resize(img,(400, 400))
            img_transformed = np.array(img/255.0, dtype = np.float32)
            images.append(img)
            noisy_images.append(img_transformed)
        except:
            pass
    images = np.array(images)
    noisy_images = np.array(noisy_images)

    return(noisy_images, images)

def imageLoader(img_dir, noise_dir, img_list, batch_size):

    L = len(img_list)

    while True:

        batch_start = 0
        batch_end = batch_size

        while batch_start < L:
            limit = min(batch_end, L)

            X, Y = load_img(img_dir, noise_dir, img_list[batch_start:limit])
            yield (X,Y) #a tuple with two numpy arrays with batch_size samples

            batch_start += batch_size
            batch_end += batch_size

# %%
# def GenerateInputs(X,y):
#     for i in range(len(X)):
#         X_input = X[i].reshape(1,500,500,3)
#         y_input = y[i].reshape(1,500,500,3)
#         yield (X_input,y_input)
batch_size = 16
steps_per_epoch = len(train)//batch_size
val_steps_per_epoch = len(val)//batch_size
train_img_datagen =imageLoader(img_dir, noise_dir, train, batch_size)
val_img_datagen = imageLoader(img_dir, noise_dir, val, batch_size)

checkpoint_best = tf.keras.callbacks.ModelCheckpoint(filepath = "/content/drive/MyDrive/Datasets/Images/Weights/" , save_weights_only=True,
                                                     verbose = 1, #save_frequency = 'epoch')
                                                      monitor = 'val_loss', save_best_only = True, mode = 'min')
stop = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss',
                                                      patience = 5, mode = 'min')

# %%
history = Model_Enhancer.fit(train_img_datagen, steps_per_epoch = steps_per_epoch, epochs = 35,
                                    validation_data = val_img_datagen, validation_steps = val_steps_per_epoch,
                                    callbacks = [checkpoint_best, stop])
# Out:
# Epoch 1/35
# 27/27 [==============================] - ETA: 0s - loss: 0.1527 - peak_signal_noise_ratio: 19.0089 - ssim: 0.7993
# Epoch 1: val_loss improved from inf to 0.08854, saving model to /content/drive/MyDrive/Datasets/Images/Weights/
# 27/27 [==============================] - 36s 452ms/step - loss: 0.1527 - peak_signal_noise_ratio: 19.0089 - ssim: 0.7993 - val_loss: 0.0885 - val_peak_signal_noise_ratio: 21.2460 - val_ssim: 0.8926
# Epoch 2/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0615 - peak_signal_noise_ratio: 24.3075 - ssim: 0.9077
# Epoch 2: val_loss improved from 0.08854 to 0.02781, saving model to /content/drive/MyDrive/Datasets/Images/Weights/
# 27/27 [==============================] - 13s 380ms/step - loss: 0.0615 - peak_signal_noise_ratio: 24.3075 - ssim: 0.9077 - val_loss: 0.0278 - val_peak_signal_noise_ratio: 28.1433 - val_ssim: 0.9351
# Epoch 3/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0222 - peak_signal_noise_ratio: 29.3924 - ssim: 0.9448
# Epoch 3: val_loss improved from 0.02781 to 0.01813, saving model to /content/drive/MyDrive/Datasets/Images/Weights/
# 27/27 [==============================] - 10s 383ms/step - loss: 0.0222 - peak_signal_noise_ratio: 29.3924 - ssim: 0.9448 - val_loss: 0.0181 - val_peak_signal_noise_ratio: 30.6403 - val_ssim: 0.9512
# Epoch 4/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0224 - peak_signal_noise_ratio: 28.8132 - ssim: 0.9470
# Epoch 4: val_loss improved from 0.01813 to 0.01671, saving model to /content/drive/MyDrive/Datasets/Images/Weights/
# 27/27 [==============================] - 10s 378ms/step - loss: 0.0224 - peak_signal_noise_ratio: 28.8132 - ssim: 0.9470 - val_loss: 0.0167 - val_peak_signal_noise_ratio: 31.2618 - val_ssim: 0.9552
# Epoch 5/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0171 - peak_signal_noise_ratio: 31.1094 - ssim: 0.9544
# Epoch 5: val_loss did not improve from 0.01671
# 27/27 [==============================] - 10s 374ms/step - loss: 0.0171 - peak_signal_noise_ratio: 31.1094 - ssim: 0.9544 - val_loss: 0.0175 - val_peak_signal_noise_ratio: 30.3376 - val_ssim: 0.9520
# Epoch 6/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0155 - peak_signal_noise_ratio: 31.8909 - ssim: 0.9579
# Epoch 6: val_loss improved from 0.01671 to 0.01505, saving model to /content/drive/MyDrive/Datasets/Images/Weights/
# 27/27 [==============================] - 10s 373ms/step - loss: 0.0155 - peak_signal_noise_ratio: 31.8909 - ssim: 0.9579 - val_loss: 0.0150 - val_peak_signal_noise_ratio: 31.7651 - val_ssim: 0.9592
# Epoch 7/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0168 - peak_signal_noise_ratio: 31.0224 - ssim: 0.9581
# Epoch 7: val_loss did not improve from 0.01505
# 27/27 [==============================] - 10s 382ms/step - loss: 0.0168 - peak_signal_noise_ratio: 31.0224 - ssim: 0.9581 - val_loss: 0.0151 - val_peak_signal_noise_ratio: 31.8951 - val_ssim: 0.9597
# Epoch 8/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0146 - peak_signal_noise_ratio: 32.2694 - ssim: 0.9609
# Epoch 8: val_loss improved from 0.01505 to 0.01348, saving model to /content/drive/MyDrive/Datasets/Images/Weights/
# 27/27 [==============================] - 10s 388ms/step - loss: 0.0146 - peak_signal_noise_ratio: 32.2694 - ssim: 0.9609 - val_loss: 0.0135 - val_peak_signal_noise_ratio: 32.7240 - val_ssim: 0.9624
# Epoch 9/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0134 - peak_signal_noise_ratio: 32.7829 - ssim: 0.9634
# Epoch 9: val_loss improved from 0.01348 to 0.01224, saving model to /content/drive/MyDrive/Datasets/Images/Weights/
# 27/27 [==============================] - 10s 381ms/step - loss: 0.0134 - peak_signal_noise_ratio: 32.7829 - ssim: 0.9634 - val_loss: 0.0122 - val_peak_signal_noise_ratio: 33.3395 - val_ssim: 0.9642
# Epoch 10/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0171 - peak_signal_noise_ratio: 30.6095 - ssim: 0.9591
# Epoch 10: val_loss did not improve from 0.01224
# 27/27 [==============================] - 10s 373ms/step - loss: 0.0171 - peak_signal_noise_ratio: 30.6095 - ssim: 0.9591 - val_loss: 0.0153 - val_peak_signal_noise_ratio: 31.6291 - val_ssim: 0.9603
# Epoch 11/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0139 - peak_signal_noise_ratio: 32.5955 - ssim: 0.9622
# Epoch 11: val_loss did not improve from 0.01224
# 27/27 [==============================] - 10s 378ms/step - loss: 0.0139 - peak_signal_noise_ratio: 32.5955 - ssim: 0.9622 - val_loss: 0.0126 - val_peak_signal_noise_ratio: 33.1401 - val_ssim: 0.9652
# Epoch 12/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0132 - peak_signal_noise_ratio: 32.9519 - ssim: 0.9647
# Epoch 12: val_loss did not improve from 0.01224
# 27/27 [==============================] - 10s 368ms/step - loss: 0.0132 - peak_signal_noise_ratio: 32.9519 - ssim: 0.9647 - val_loss: 0.0171 - val_peak_signal_noise_ratio: 30.1068 - val_ssim: 0.9597
# Epoch 13/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0136 - peak_signal_noise_ratio: 32.4188 - ssim: 0.9640
# Epoch 13: val_loss did not improve from 0.01224
# 27/27 [==============================] - 10s 372ms/step - loss: 0.0136 - peak_signal_noise_ratio: 32.4188 - ssim: 0.9640 - val_loss: 0.0152 - val_peak_signal_noise_ratio: 30.2787 - val_ssim: 0.9664
# Epoch 14/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0123 - peak_signal_noise_ratio: 32.8794 - ssim: 0.9666
# Epoch 14: val_loss improved from 0.01224 to 0.01163, saving model to /content/drive/MyDrive/Datasets/Images/Weights/
# 27/27 [==============================] - 10s 377ms/step - loss: 0.0123 - peak_signal_noise_ratio: 32.8794 - ssim: 0.9666 - val_loss: 0.0116 - val_peak_signal_noise_ratio: 33.1908 - val_ssim: 0.9686
# Epoch 15/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0121 - peak_signal_noise_ratio: 32.8594 - ssim: 0.9676
# Epoch 15: val_loss did not improve from 0.01163
# 27/27 [==============================] - 10s 371ms/step - loss: 0.0121 - peak_signal_noise_ratio: 32.8594 - ssim: 0.9676 - val_loss: 0.0138 - val_peak_signal_noise_ratio: 30.9072 - val_ssim: 0.9663
# Epoch 16/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0116 - peak_signal_noise_ratio: 33.3322 - ssim: 0.9681
# Epoch 16: val_loss did not improve from 0.01163
# 27/27 [==============================] - 10s 373ms/step - loss: 0.0116 - peak_signal_noise_ratio: 33.3322 - ssim: 0.9681 - val_loss: 0.0134 - val_peak_signal_noise_ratio: 31.7681 - val_ssim: 0.9689
# Epoch 17/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0157 - peak_signal_noise_ratio: 30.4296 - ssim: 0.9653
# Epoch 17: val_loss did not improve from 0.01163
# 27/27 [==============================] - 10s 374ms/step - loss: 0.0157 - peak_signal_noise_ratio: 30.4296 - ssim: 0.9653 - val_loss: 0.0142 - val_peak_signal_noise_ratio: 30.8330 - val_ssim: 0.9661
# Epoch 18/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0116 - peak_signal_noise_ratio: 33.3447 - ssim: 0.9697
# Epoch 18: val_loss did not improve from 0.01163
# 27/27 [==============================] - 10s 371ms/step - loss: 0.0116 - peak_signal_noise_ratio: 33.3447 - ssim: 0.9697 - val_loss: 0.0155 - val_peak_signal_noise_ratio: 30.5287 - val_ssim: 0.9656
# Epoch 19/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0127 - peak_signal_noise_ratio: 32.3804 - ssim: 0.9689
# Epoch 19: val_loss improved from 0.01163 to 0.01110, saving model to /content/drive/MyDrive/Datasets/Images/Weights/
# 27/27 [==============================] - 10s 378ms/step - loss: 0.0127 - peak_signal_noise_ratio: 32.3804 - ssim: 0.9689 - val_loss: 0.0111 - val_peak_signal_noise_ratio: 33.4920 - val_ssim: 0.9711
# Epoch 20/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0106 - peak_signal_noise_ratio: 33.9843 - ssim: 0.9706
# Epoch 20: val_loss did not improve from 0.01110
# 27/27 [==============================] - 10s 373ms/step - loss: 0.0106 - peak_signal_noise_ratio: 33.9843 - ssim: 0.9706 - val_loss: 0.0116 - val_peak_signal_noise_ratio: 32.2491 - val_ssim: 0.9720
# Epoch 21/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0097 - peak_signal_noise_ratio: 34.4682 - ssim: 0.9715
# Epoch 21: val_loss improved from 0.01110 to 0.00833, saving model to /content/drive/MyDrive/Datasets/Images/Weights/
# 27/27 [==============================] - 10s 376ms/step - loss: 0.0097 - peak_signal_noise_ratio: 34.4682 - ssim: 0.9715 - val_loss: 0.0083 - val_peak_signal_noise_ratio: 35.4841 - val_ssim: 0.9742
# Epoch 22/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0088 - peak_signal_noise_ratio: 35.1033 - ssim: 0.9728
# Epoch 22: val_loss did not improve from 0.00833
# 27/27 [==============================] - 10s 371ms/step - loss: 0.0088 - peak_signal_noise_ratio: 35.1033 - ssim: 0.9728 - val_loss: 0.0118 - val_peak_signal_noise_ratio: 31.6176 - val_ssim: 0.9707
# Epoch 23/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0110 - peak_signal_noise_ratio: 33.0771 - ssim: 0.9706
# Epoch 23: val_loss improved from 0.00833 to 0.00681, saving model to /content/drive/MyDrive/Datasets/Images/Weights/
# 27/27 [==============================] - 10s 377ms/step - loss: 0.0110 - peak_signal_noise_ratio: 33.0771 - ssim: 0.9706 - val_loss: 0.0068 - val_peak_signal_noise_ratio: 36.9465 - val_ssim: 0.9746
# Epoch 24/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0105 - peak_signal_noise_ratio: 33.6564 - ssim: 0.9723
# Epoch 24: val_loss did not improve from 0.00681
# 27/27 [==============================] - 10s 384ms/step - loss: 0.0105 - peak_signal_noise_ratio: 33.6564 - ssim: 0.9723 - val_loss: 0.0104 - val_peak_signal_noise_ratio: 33.3535 - val_ssim: 0.9746
# Epoch 25/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0098 - peak_signal_noise_ratio: 34.1068 - ssim: 0.9733
# Epoch 25: val_loss did not improve from 0.00681
# 27/27 [==============================] - 10s 377ms/step - loss: 0.0098 - peak_signal_noise_ratio: 34.1068 - ssim: 0.9733 - val_loss: 0.0095 - val_peak_signal_noise_ratio: 34.3234 - val_ssim: 0.9751
# Epoch 26/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0108 - peak_signal_noise_ratio: 33.2867 - ssim: 0.9729
# Epoch 26: val_loss did not improve from 0.00681
# 27/27 [==============================] - 10s 374ms/step - loss: 0.0108 - peak_signal_noise_ratio: 33.2867 - ssim: 0.9729 - val_loss: 0.0073 - val_peak_signal_noise_ratio: 36.5649 - val_ssim: 0.9767
# Epoch 27/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0090 - peak_signal_noise_ratio: 34.8193 - ssim: 0.9746
# Epoch 27: val_loss did not improve from 0.00681
# 27/27 [==============================] - 10s 373ms/step - loss: 0.0090 - peak_signal_noise_ratio: 34.8193 - ssim: 0.9746 - val_loss: 0.0092 - val_peak_signal_noise_ratio: 34.5721 - val_ssim: 0.9764
# Epoch 28/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0096 - peak_signal_noise_ratio: 34.3251 - ssim: 0.9746
# Epoch 28: val_loss improved from 0.00681 to 0.00663, saving model to /content/drive/MyDrive/Datasets/Images/Weights/
# 27/27 [==============================] - 10s 371ms/step - loss: 0.0096 - peak_signal_noise_ratio: 34.3251 - ssim: 0.9746 - val_loss: 0.0066 - val_peak_signal_noise_ratio: 37.1165 - val_ssim: 0.9778
# Epoch 29/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0089 - peak_signal_noise_ratio: 34.9023 - ssim: 0.9753
# Epoch 29: val_loss did not improve from 0.00663
# 27/27 [==============================] - 10s 378ms/step - loss: 0.0089 - peak_signal_noise_ratio: 34.9023 - ssim: 0.9753 - val_loss: 0.0081 - val_peak_signal_noise_ratio: 35.7422 - val_ssim: 0.9755
# Epoch 30/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0086 - peak_signal_noise_ratio: 35.1773 - ssim: 0.9760
# Epoch 30: val_loss did not improve from 0.00663
# 27/27 [==============================] - 10s 385ms/step - loss: 0.0086 - peak_signal_noise_ratio: 35.1773 - ssim: 0.9760 - val_loss: 0.0082 - val_peak_signal_noise_ratio: 35.4187 - val_ssim: 0.9766
# Epoch 31/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0084 - peak_signal_noise_ratio: 35.3288 - ssim: 0.9769
# Epoch 31: val_loss did not improve from 0.00663
# 27/27 [==============================] - 10s 375ms/step - loss: 0.0084 - peak_signal_noise_ratio: 35.3288 - ssim: 0.9769 - val_loss: 0.0092 - val_peak_signal_noise_ratio: 33.9296 - val_ssim: 0.9761
# Epoch 32/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0085 - peak_signal_noise_ratio: 35.1909 - ssim: 0.9768
# Epoch 32: val_loss did not improve from 0.00663
# 27/27 [==============================] - 10s 374ms/step - loss: 0.0085 - peak_signal_noise_ratio: 35.1909 - ssim: 0.9768 - val_loss: 0.0081 - val_peak_signal_noise_ratio: 35.6080 - val_ssim: 0.9789
# Epoch 33/35
# 27/27 [==============================] - ETA: 0s - loss: 0.0087 - peak_signal_noise_ratio: 34.9408 - ssim: 0.9770
# Epoch 33: val_loss did not improve from 0.00663
# 27/27 [==============================] - 10s 378ms/step - loss: 0.0087 - peak_signal_noise_ratio: 34.9408 - ssim: 0.9770 - val_loss: 0.0088 - val_peak_signal_noise_ratio: 34.5433 - val_ssim: 0.9779

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.grid()
plt.legend()

# %%
plt.plot(history.history['peak_signal_noise_ratio'], label='PSNR')
plt.plot(history.history['val_peak_signal_noise_ratio'], label='Val-PSNR')
plt.title('PSNR')
plt.grid()
plt.legend()

# %%
plt.plot(history.history['ssim'], label='SSIM')
plt.plot(history.history['val_ssim'], label='Val-SSIM')
plt.title('SSIM')
plt.grid()
plt.legend()

# %%
Model_Enhancer.save_weights("/content/Models/")

# %%
TestPath="/content/drive/MyDrive/Datasets/LowLight/eval15/low/"

# %%
def ExtractTestInput(ImagePath):
    img = cv.imread(ImagePath)
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    img = cv.resize(img,(256, 256))
    img = np.array(img/255.0, dtype= np.float32)
    gamma = random.choice([2,3,4,5])
    Noise = noisy(img, gamma)
    # Noise = noisy(Noise, noise_typ= 'gauss')
    # Noise = (Noise-Noise.min())/(Noise.max()-Noise.min())
    Noise = Noise.reshape(1,256, 256,3)
    return Noise

# %%
ImagePath="/content/images/images/architecure/10110743246_82460e08e7_m.jpg"#TestPath+"0013.jpg"
image_for_test = ExtractTestInput(ImagePath)
Prediction = Model_Enhancer.predict(image_for_test)

# %%
mpl.rcParams['axes.spines.left'] = False # Turn off the left axis
mpl.rcParams['axes.spines.right'] = False # Turn off the right axis
mpl.rcParams['axes.spines.bottom'] = False # Turn off the bottom axis
mpl.rcParams['axes.spines.top'] = False # Turn off the top axis
mpl.rcParams['xtick.bottom'] = False # Turn off the xticks
mpl.rcParams['ytick.left'] = False # Turn off the yticks

# %% [markdown]
# Prediction = Prediction.reshape(500,500,3)
# #print(f'PSNR: {peak_signal_noise_ratio(image_for_test, Prediction).item()}')
# plt.imshow((1/255)*Prediction)

# %%
test_list = os.listdir(TestPath)

# %% [markdown]
# ## COMPARATIVE ANALYSIS OF THE ENHANCED IMAGE WITH RESPECT TO GROUND TRUTH IMAGE

# %%
def PSNR(original, reconstructed):
    return tf.image.psnr(original, reconstructed, max_val=1.0)

# %%
def ExtractTestInput(ImagePath):
    img = cv.imread(ImagePath)
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    img = cv.resize(img,(400, 400))
    img = np.array(img/255.0, dtype= np.float32)
    Noise = img.reshape(1,400, 400,3)
    return Noise

# %%
TestPath2="/content/drive/MyDrive/Datasets/LowLight/eval15/high/"

# %%
Image_test= random.choice(val)
plt.figure(figsize=(30,30))
plt.subplot(1, 3 ,1)
Image_test = random.choice(test_list)
img_1 = cv.imread(TestPath2 + Image_test)
img_1 = cv.cvtColor(img_1, cv.COLOR_BGR2RGB)
img_1 = cv.resize(img_1, (400, 400))
plt.title("Ground Truth",fontsize=20)
plt.imshow(img_1)

plt.subplot(1, 3, 2)
img_ = ExtractTestInput(TestPath + Image_test)
Prediction = Model_Enhancer.predict(img_)
img_ = img_.reshape(400, 400,3)
plt.title("Low Light Image",fontsize=20)
plt.imshow(img_)

plt.subplot(1, 3, 3)
Prediction = Prediction.reshape(400, 400,3)
plt.title("Enhanced Image",fontsize=20)
plt.imshow(Prediction)
print(f'PSNR of noisy image: {PSNR(img_, Prediction)}')
print(f'PSNR of reconstructed image: {PSNR(img_1, Prediction)}')

# %%
Image_test= random.choice(val)
plt.figure(figsize=(30,30))
plt.subplot(1, 3 ,1)
img_1 = cv.imread(InputPath + Image_test)
img_1 = cv.cvtColor(img_1, cv.COLOR_BGR2RGB)
img_1 = cv.resize(img_1, (256, 256))
plt.title("Ground Truth",fontsize=20)
plt.imshow(img_1)

plt.subplot(1, 3, 2)
img_ = ExtractTestInput(InputPath + Image_test)
Prediction = Model_Enhancer.predict(img_)
img_ = img_.reshape(256, 256,3)
plt.title("Low Light Image",fontsize=20)
plt.imshow(img_)

plt.subplot(1, 3, 3)
Prediction = Prediction.reshape(256, 256,3)
plt.title("Enhanced Image",fontsize=20)
plt.imshow(Prediction)
print(f'PSNR of noisy image: {PSNR(img_, Prediction)}')
print(f'PSNR of reconstructed image: {PSNR(img_1, Prediction)}')

# %%
Image_test2=TestPath2+"13.jpg"
plt.figure(figsize=(30,30))
plt.subplot(5,5,1)
img_1 = cv.imread(Image_test2)
img_1 = cv.cvtColor(img_1, cv.COLOR_BGR2RGB)
img_1 = cv.resize(img_1, (512, 512))
plt.title("Ground Truth",fontsize=20)
plt.imshow(img_1)

plt.subplot(5,5,1+1)
img_ = ExtractTestInput(Image_test2)
Prediction = Model_Enhancer.predict(img_)
img_ = img_.reshape(512,512,3)
plt.title("Low Light Image",fontsize=20)
plt.imshow(img_)

plt.subplot(5,5,1+2)
Prediction = Prediction.reshape(512,512,3)
img_[:,:,:] = Prediction[:,:,:]
plt.title("Enhanced Image",fontsize=20)
plt.imshow(img_)
print(f'PSNR: {PSNR(img_1, Prediction)}')

# %% [markdown]
# ### LOAD MODEL - Infernce

# %%
model = create_model((512, 512, 3))
model.load_weights('/content/drive/MyDrive/Datasets/Images/Weights/')

Image_test2= "Places365_val_00013367.jpg" #random.choice(val)
plt.figure(figsize=(30,30))
plt.subplot(1, 3 ,1)
img_1 = cv.imread(InputPath+Image_test2)
img_1 = cv.cvtColor(img_1, cv.COLOR_BGR2RGB)
img_1 = cv.resize(img_1, (512,512))
plt.title("Ground Truth: " + Image_test2 ,fontsize=20)
plt.imshow(img_1)

plt.subplot(1, 3, 2)
img_ = noisy(img_1, 3)
img_ = img_.reshape(1,512,512,3)
Prediction = model.predict(img_)
img_ = img_.reshape(512,512,3)
plt.title("Low Light Image",fontsize=20)
plt.imshow(img_)

plt.subplot(1, 3, 3)
Prediction = Prediction.reshape(512,512,3)
plt.title("Enhanced Image",fontsize=20)
plt.imshow(img_)
print(f'PSNR of noisy image: {PSNR(img_, Prediction)}')
print(f'PSNR of reconstructed image: {PSNR(img_1, Prediction)}')
